# %% [markdown]
# # Unreliable midpoint
# Reproduce the two-node tutorial, then run the same config with a midpoint that emits heralds it did not detect.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
from unreliable_midpoint.run_example import run

# %% [markdown]
# An honest run reproduces the tutorial count.

# %%
delivered, tl = run(p_false_positive=0.0)
print('honest delivered:', delivered)
# Out:
# honest delivered: 105

# %% [markdown]
# With a false-positive rate the midpoint delivers pairs it did not detect. The ledger counts them.

# %%
for p in (0.0, 0.1, 0.5):
    delivered, tl = run(p_false_positive=p)
    print(f'p_false_positive={p}: delivered {delivered}, unbacked heralds {tl.physics_ledger.false_positive}')
# Out:
# p_false_positive=0.0: delivered 105, unbacked heralds 0
# p_false_positive=0.1: delivered 143, unbacked heralds 24
# p_false_positive=0.5: delivered 244, unbacked heralds 125
